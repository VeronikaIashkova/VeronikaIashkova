# %% [markdown]
# # Анализ бизнес показателей
#
# # Описание проекта
# Вы работаете в стартапе, который продаёт продукты питания. Нужно разобраться, как ведут себя пользователи вашего мобильного приложения.
# Изучите воронку продаж. Узнайте, как пользователи доходят до покупки. Сколько пользователей доходит до покупки, а сколько — «застревает» на предыдущих шагах? На каких именно?
# После этого исследуйте результаты A/A/B-эксперимента. Дизайнеры захотели поменять шрифты во всём приложении, а менеджеры испугались, что пользователям будет непривычно. Договорились принять решение по результатам A/A/B-теста. Пользователей разбили на 3 группы: 2 контрольные со старыми шрифтами и одну экспериментальную — с новыми. Выясните, какой шрифт лучше.
# Создание двух групп A вместо одной имеет определённые преимущества. Если две контрольные группы окажутся равны, вы можете быть уверены в точности проведенного тестирования. Если же между значениями A и A будут существенные различия, это поможет обнаружить факторы, которые привели к искажению результатов. Сравнение контрольных групп также помогает понять, сколько времени и данных потребуется для дальнейших тестов.
# В случае общей аналитики и A/A/B-эксперимента работайте с одними и теми же данными. В реальных проектах всегда идут эксперименты. Аналитики исследуют качество работы приложения по общим данным, не учитывая принадлежность пользователей к экспериментам.
#
# # Описание данных
# Каждая запись в логе — это действие пользователя, или событие.
# •	EventName — название события;
# •	DeviceIDHash — уникальный идентификатор пользователя;
# •	EventTimestamp — время события;
# •	ExpId — номер эксперимента: 246 и 247 — контрольные группы, а 248 — экспериментальная.
#
# # Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/logs_exp.csv. Скачать датасет
#
# # Шаг 2. Подготовьте данные
#
# •	Замените названия столбцов на удобные для вас;
#
# •	Проверьте пропуски и типы данных. Откорректируйте, если нужно;
#
# •	Добавьте столбец даты и времени, а также отдельный столбец дат;
#
# # Шаг 3. Изучите и проверьте данные
#
# •	Сколько всего событий в логе?
#
# •	Сколько всего пользователей в логе?
#
# •	Сколько в среднем событий приходится на пользователя?
#
# •	Данными за какой период вы располагаете? Найдите максимальную и минимальную дату. Изучите, как меняется количество данных: постройте столбчатую диаграмму, которая отобразит количество событий в зависимости от времени в разрезе групп. Можно ли быть уверенным, что у вас одинаково полные данные за весь период? Технически в логи новых дней по некоторым пользователям могут «доезжать» события из прошлого — это может «перекашивать данные». Определите, с какого момента данные полные и отбросьте более старые. Данными за какой период времени вы располагаете на самом деле?
#
# •	Много ли событий и пользователей вы потеряли, отбросив старые данные?
#
# •	Проверьте, что у вас есть пользователи из всех трёх экспериментальных групп.
#
# # Шаг 4. Изучите воронку событий
#
# •	Посмотрите, какие события есть в логах, как часто они встречаются. Отсортируйте события по частоте.
#
# •	Посчитайте, сколько пользователей совершали каждое из этих событий. Отсортируйте события по числу пользователей. Посчитайте долю пользователей, которые хоть раз совершали событие.
#
# •	Предположите, в каком порядке происходят события. Все ли они выстраиваются в последовательную цепочку? Их не нужно учитывать при расчёте воронки.
#
# •	По воронке событий посчитайте, какая доля пользователей проходит на следующий шаг воронки (от числа пользователей на предыдущем). То есть для последовательности событий A → B → C посчитайте отношение числа пользователей с событием B к количеству пользователей с событием A, а также отношение числа пользователей с событием C к количеству пользователей с событием B.
#
# •	На каком шаге теряете больше всего пользователей?
#
# •	Какая доля пользователей доходит от первого события до оплаты?
#
# # Шаг 5. Изучите результаты эксперимента
#
# •	Сколько пользователей в каждой экспериментальной группе?
#
# •	Есть 2 контрольные группы для А/А-эксперимента, чтобы проверить корректность всех механизмов и расчётов. Проверьте, находят ли статистические критерии разницу между выборками 246 и 247.
#
# •	Выберите самое популярное событие. Посчитайте число пользователей, совершивших это событие в каждой из контрольных групп. Посчитайте долю пользователей, совершивших это событие. Проверьте, будет ли отличие между группами статистически достоверным. Проделайте то же самое для всех других событий (удобно обернуть проверку в отдельную функцию). Можно ли сказать, что разбиение на группы работает корректно?
#
# •	Аналогично поступите с группой с изменённым шрифтом. Сравните результаты с каждой из контрольных групп в отдельности по каждому событию. Сравните результаты с объединённой контрольной группой. Какие выводы из эксперимента можно сделать?
#
# •	Какой уровень значимости вы выбрали при проверке статистических гипотез выше? Посчитайте, сколько проверок статистических гипотез вы сделали. При уровне значимости 0.1 в 10% случаев можно ошибочно отклонить нулевую гипотезу при условии, что она верна. Какой уровень значимости стоит применить? Если вы хотите изменить его, проделайте предыдущие пункты и проверьте свои выводы.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузите-данные" data-toc-modified-id="Загрузите-данные-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузите данные</a></span><ul class="toc-item"><li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка данных</a></span></li></ul></li><li><span><a href="#Подготовка-данных-к-анализу" data-toc-modified-id="Подготовка-данных-к-анализу-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных к анализу</a></span><ul class="toc-item"><li><span><a href="#Замените-названия-столбцов-на-удобные-для-вас." data-toc-modified-id="Замените-названия-столбцов-на-удобные-для-вас.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Замените названия столбцов на удобные для вас.</a></span></li><li><span><a href="#Проверьте-пропуски-и-типы-данных.-Откорректируйте,-если-нужно." data-toc-modified-id="Проверьте-пропуски-и-типы-данных.-Откорректируйте,-если-нужно.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверьте пропуски и типы данных. Откорректируйте, если нужно.</a></span></li><li><span><a href="#Добавьте-столбец-даты-и-времени,-а-также-отдельный-столбец-дат." data-toc-modified-id="Добавьте-столбец-даты-и-времени,-а-также-отдельный-столбец-дат.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Добавьте столбец даты и времени, а также отдельный столбец дат.</a></span></li></ul></li><li><span><a href="#Изучите-и-проверьте-данные." data-toc-modified-id="Изучите-и-проверьте-данные.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Изучите и проверьте данные.</a></span><ul class="toc-item"><li><span><a href="#Сколько-всего-событий-в-логе." data-toc-modified-id="Сколько-всего-событий-в-логе.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Сколько всего событий в логе.</a></span></li><li><span><a href="#Сколько-всего-пользователей-в-логе." data-toc-modified-id="Сколько-всего-пользователей-в-логе.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Сколько всего пользователей в логе.</a></span></li><li><span><a href="#Сколько-в-среднем-событий-приходится-на-пользователя." data-toc-modified-id="Сколько-в-среднем-событий-приходится-на-пользователя.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Сколько в среднем событий приходится на пользователя.</a></span></li><li><span><a href="#Данными-за-какой-период-вы-располагаете." data-toc-modified-id="Данными-за-какой-период-вы-располагаете.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Данными за какой период вы располагаете.</a></span></li><li><span><a href="#Изучите,-как-меняется-количество-данных.Постройте-столбчатую-диаграмму,-которая-отобразит-количество-событий-в-зависимости-от-времени-в-разрезе-групп." data-toc-modified-id="Изучите,-как-меняется-количество-данных.Постройте-столбчатую-диаграмму,-которая-отобразит-количество-событий-в-зависимости-от-времени-в-разрезе-групп.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Изучите, как меняется количество данных.Постройте столбчатую диаграмму, которая отобразит количество событий в зависимости от времени в разрезе групп.</a></span></li><li><span><a href="#Определите,-с-какого-момента-данные-полные-и-отбросьте-более-старые.-Данными-за-какой-период-времени-вы-располагаете-на-самом-деле." data-toc-modified-id="Определите,-с-какого-момента-данные-полные-и-отбросьте-более-старые.-Данными-за-какой-период-времени-вы-располагаете-на-самом-деле.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Определите, с какого момента данные полные и отбросьте более старые. Данными за какой период времени вы располагаете на самом деле.</a></span></li><li><span><a href="#Много-ли-событий-и-пользователей-вы-потеряли,-отбросив-старые-данные." data-toc-modified-id="Много-ли-событий-и-пользователей-вы-потеряли,-отбросив-старые-данные.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Много ли событий и пользователей вы потеряли, отбросив старые данные.</a></span></li><li><span><a href="#Проверьте,-что-у-вас-есть-пользователи-из-всех-трёх-экспериментальных-групп." data-toc-modified-id="Проверьте,-что-у-вас-есть-пользователи-из-всех-трёх-экспериментальных-групп.-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Проверьте, что у вас есть пользователи из всех трёх экспериментальных групп.</a></span></li></ul></li><li><span><a href="#Изучите-воронку-событий" data-toc-modified-id="Изучите-воронку-событий-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Изучите воронку событий</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-какие-события-есть-в-логах,-как-часто-они-встречаются.-Отсортируйте-события-по-частоте." data-toc-modified-id="Посмотрите,-какие-события-есть-в-логах,-как-часто-они-встречаются.-Отсортируйте-события-по-частоте.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посмотрите, какие события есть в логах, как часто они встречаются. Отсортируйте события по частоте.</a></span></li><li><span><a href="#Посчитайте,-сколько-пользователей-совершали-каждое-из-этих-событий." data-toc-modified-id="Посчитайте,-сколько-пользователей-совершали-каждое-из-этих-событий.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Посчитайте, сколько пользователей совершали каждое из этих событий.</a></span></li><li><span><a href="#Отсортируйте-события-по-числу-пользователей." data-toc-modified-id="Отсортируйте-события-по-числу-пользователей.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Отсортируйте события по числу пользователей.</a></span></li><li><span><a href="#Посчитайте-долю-пользователей,-которые-хоть-раз-совершали-событие." data-toc-modified-id="Посчитайте-долю-пользователей,-которые-хоть-раз-совершали-событие.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Посчитайте долю пользователей, которые хоть раз совершали событие.</a></span></li></ul></li><li><span><a href="#-Комментарий-ревьюера-✔️" data-toc-modified-id="-Комментарий-ревьюера-✔️-5"><span class="toc-item-num">5&nbsp;&nbsp;</span> Комментарий ревьюера ✔️</a></span><ul class="toc-item"><li><span><a href="#Предположите,-в-каком-порядке-происходят-события.-Все-ли-они-выстраиваются-в-последовательную-цепочку?-Их-не-нужно-учитывать-при-расчёте-воронки." data-toc-modified-id="Предположите,-в-каком-порядке-происходят-события.-Все-ли-они-выстраиваются-в-последовательную-цепочку?-Их-не-нужно-учитывать-при-расчёте-воронки.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Предположите, в каком порядке происходят события. Все ли они выстраиваются в последовательную цепочку? Их не нужно учитывать при расчёте воронки.</a></span></li><li><span><a href="#По-воронке-событий-посчитайте,-какая-доля-пользователей-проходит-на-следующий-шаг-воронки-(от-числа-пользователей-на-предыдущем).-То-есть-для-последовательности-событий-A-→-B-→-C-посчитайте-отношение-числа-пользователей-с-событием-B-к-количеству-пользователей-с-событием-A,-а-также-отношение-числа-пользователей-с-событием-C-к-количеству-пользователей-с-событием-B." data-toc-modified-id="По-воронке-событий-посчитайте,-какая-доля-пользователей-проходит-на-следующий-шаг-воронки-(от-числа-пользователей-на-предыдущем).-То-есть-для-последовательности-событий-A-→-B-→-C-посчитайте-отношение-числа-пользователей-с-событием-B-к-количеству-пользователей-с-событием-A,-а-также-отношение-числа-пользователей-с-событием-C-к-количеству-пользователей-с-событием-B.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>По воронке событий посчитайте, какая доля пользователей проходит на следующий шаг воронки (от числа пользователей на предыдущем). То есть для последовательности событий A → B → C посчитайте отношение числа пользователей с событием B к количеству пользователей с событием A, а также отношение числа пользователей с событием C к количеству пользователей с событием B.</a></span></li></ul></li><li><span><a href="#Изучите-результаты-эксперимента" data-toc-modified-id="Изучите-результаты-эксперимента-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Изучите результаты эксперимента</a></span><ul class="toc-item"><li><span><a href="#Сколько-пользователей-в-каждой-экспериментальной-группе?" data-toc-modified-id="Сколько-пользователей-в-каждой-экспериментальной-группе?-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Сколько пользователей в каждой экспериментальной группе?</a></span></li><li><span><a href="#Есть-2-контрольные-группы-для-А/А-эксперимента,-чтобы-проверить-корректность-всех-механизмов-и-расчётов.-Проверьте,-находят-ли-статистические-критерии-разницу-между-выборками-246-и-247." data-toc-modified-id="Есть-2-контрольные-группы-для-А/А-эксперимента,-чтобы-проверить-корректность-всех-механизмов-и-расчётов.-Проверьте,-находят-ли-статистические-критерии-разницу-между-выборками-246-и-247.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Есть 2 контрольные группы для А/А-эксперимента, чтобы проверить корректность всех механизмов и расчётов. Проверьте, находят ли статистические критерии разницу между выборками 246 и 247.</a></span></li><li><span><a href="#Выберите-самое-популярное-событие." data-toc-modified-id="Выберите-самое-популярное-событие.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Выберите самое популярное событие.</a></span></li><li><span><a href="#Посчитайте-число-пользователей,-совершивших-это-событие-в-каждой-из-контрольных-групп." data-toc-modified-id="Посчитайте-число-пользователей,-совершивших-это-событие-в-каждой-из-контрольных-групп.-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Посчитайте число пользователей, совершивших это событие в каждой из контрольных групп.</a></span></li><li><span><a href="#Посчитайте-долю-пользователей,-совершивших-это-событие." data-toc-modified-id="Посчитайте-долю-пользователей,-совершивших-это-событие.-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Посчитайте долю пользователей, совершивших это событие.</a></span></li><li><span><a href="#Проверьте,-будет-ли-отличие-между-группами-статистически-достоверным.-Проделайте-то-же-самое-для-всех-других-событий-(удобно-обернуть-проверку-в-отдельную-функцию).-Можно-ли-сказать,-что-разбиение-на-группы-работает-корректно?" data-toc-modified-id="Проверьте,-будет-ли-отличие-между-группами-статистически-достоверным.-Проделайте-то-же-самое-для-всех-других-событий-(удобно-обернуть-проверку-в-отдельную-функцию).-Можно-ли-сказать,-что-разбиение-на-группы-работает-корректно?-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Проверьте, будет ли отличие между группами статистически достоверным. Проделайте то же самое для всех других событий (удобно обернуть проверку в отдельную функцию). Можно ли сказать, что разбиение на группы работает корректно?</a></span></li><li><span><a href="#Аналогично-поступите-с-группой-с-изменённым-шрифтом.-Сравните-результаты-с-каждой-из-контрольных-групп-в-отдельности-по-каждому-событию." data-toc-modified-id="Аналогично-поступите-с-группой-с-изменённым-шрифтом.-Сравните-результаты-с-каждой-из-контрольных-групп-в-отдельности-по-каждому-событию.-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Аналогично поступите с группой с изменённым шрифтом. Сравните результаты с каждой из контрольных групп в отдельности по каждому событию.</a></span><ul class="toc-item"><li><span><a href="#Сравнение-246-и-248-групп." data-toc-modified-id="Сравнение-246-и-248-групп.-6.7.1"><span class="toc-item-num">6.7.1&nbsp;&nbsp;</span>Сравнение 246 и 248 групп.</a></span></li><li><span><a href="#Сравнение-247-и-248-групп." data-toc-modified-id="Сравнение-247-и-248-групп.-6.7.2"><span class="toc-item-num">6.7.2&nbsp;&nbsp;</span>Сравнение 247 и 248 групп.</a></span></li></ul></li><li><span><a href="#Сравните-результаты-с-объединённой-контрольной-группой.-Какие-выводы-из-эксперимента-можно-сделать?" data-toc-modified-id="Сравните-результаты-с-объединённой-контрольной-группой.-Какие-выводы-из-эксперимента-можно-сделать?-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Сравните результаты с объединённой контрольной группой. Какие выводы из эксперимента можно сделать?</a></span></li><li><span><a href="#Посчитайте,-сколько-проверок-статистических-гипотез-вы-сделали." data-toc-modified-id="Посчитайте,-сколько-проверок-статистических-гипотез-вы-сделали.-6.9"><span class="toc-item-num">6.9&nbsp;&nbsp;</span>Посчитайте, сколько проверок статистических гипотез вы сделали.</a></span></li><li><span><a href="#Какой-уровень-значимости-вы-выбрали-при-проверке-статистических-гипотез-выше?--При-уровне-значимости-0.1-в-10%-случаев-можно-ошибочно-отклонить-нулевую-гипотезу-при-условии,-что-она-верна.-Какой-уровень-значимости-стоит-применить?-Если-вы-хотите-изменить-его,-проделайте-предыдущие-пункты-и-проверьте-свои-выводы." data-toc-modified-id="Какой-уровень-значимости-вы-выбрали-при-проверке-статистических-гипотез-выше?--При-уровне-значимости-0.1-в-10%-случаев-можно-ошибочно-отклонить-нулевую-гипотезу-при-условии,-что-она-верна.-Какой-уровень-значимости-стоит-применить?-Если-вы-хотите-изменить-его,-проделайте-предыдущие-пункты-и-проверьте-свои-выводы.-6.10"><span class="toc-item-num">6.10&nbsp;&nbsp;</span>Какой уровень значимости вы выбрали при проверке статистических гипотез выше?  При уровне значимости 0.1 в 10% случаев можно ошибочно отклонить нулевую гипотезу при условии, что она верна. Какой уровень значимости стоит применить? Если вы хотите изменить его, проделайте предыдущие пункты и проверьте свои выводы.</a></span></li></ul></li><li><span><a href="#Итоговый-вывод:" data-toc-modified-id="Итоговый-вывод:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Итоговый вывод:</a></span></li></ul></div>

# %% [markdown]
# ## Загрузите данные
# ### Загрузка библиотек

# %%
import numpy as np
import math as mth
from datetime import datetime, timedelta
import warnings

import pandas as pd
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters
from scipy import stats as st
from statsmodels.stats.proportion import proportions_ztest


# конвертеры, которые позволяют использовать типы pandas в matplotlib  
register_matplotlib_converters()
pd.options.display.max_colwidth = 100

# %% [markdown]
# ### Загрузка данных

# %%
try:
    logs_exp = pd.read_csv("https://code.s3.yandex.net/datasets/logs_exp.csv", sep="\t")
except:
    logs_exp = pd.read_csv("/datasets/logs_exp.csv", sep="\t")

# %% [markdown]
# # Промежуточный вывод 1:
# Данные загружены.

# %% [markdown]
# ## Подготовка данных к анализу
# ###  Замените названия столбцов на удобные для вас.

# %%
logs_exp.head(5)
# Out:
#                  EventName         DeviceIDHash  EventTimestamp  ExpId
# 0         MainScreenAppear  4575588528974610257      1564029816    246
# 1         MainScreenAppear  7416695313311560658      1564053102    246
# 2  PaymentScreenSuccessful  3518123091307005509      1564054127    248
# 3         CartScreenAppear  3518123091307005509      1564054127    248
# 4  PaymentScreenSuccessful  6217807653094995999      1564055322    248

# %%
logs_exp = logs_exp.rename(columns={'EventName': 'event_name', 'DeviceIDHash': 'user_ID', 'EventTimestamp': 'timestamp', 'ExpId': 'group'})
logs_exp.head(5)
# Out:
#                 event_name              user_ID   timestamp  group
# 0         MainScreenAppear  4575588528974610257  1564029816    246
# 1         MainScreenAppear  7416695313311560658  1564053102    246
# 2  PaymentScreenSuccessful  3518123091307005509  1564054127    248
# 3         CartScreenAppear  3518123091307005509  1564054127    248
# 4  PaymentScreenSuccessful  6217807653094995999  1564055322    248

# %% [markdown]
# ### Проверьте пропуски и типы данных. Откорректируйте, если нужно.

# %%
logs_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244126 entries, 0 to 244125
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   event_name  244126 non-null  object
#  1   user_ID     244126 non-null  int64
#  2   timestamp   244126 non-null  int64
#  3   group       244126 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 7.5+ MB

# %%
number_of_duplicates = logs_exp.duplicated().sum()
print('Количество дубликатов:', number_of_duplicates)
# Out:
# Количество дубликатов: 413

# %%
proportion_of_duplicates = number_of_duplicates / 244126
print('Доля дубликатов от исходных данных:', proportion_of_duplicates)
# Out:
# Доля дубликатов от исходных данных: 0.0016917493425526163

# %%
duplicates = logs_exp[logs_exp.duplicated()]
print(duplicates)
# Out:
#                      event_name              user_ID   timestamp  group
# 453            MainScreenAppear  5613408041324010552  1564474784    248
# 2350           CartScreenAppear  1694940645335807244  1564609899    248
# 3573           MainScreenAppear   434103746454591587  1564628377    248
# 4076           MainScreenAppear  3761373764179762633  1564631266    247
# 4803           MainScreenAppear  2835328739789306622  1564634641    248
# ...                         ...                  ...         ...    ...
# 242329         MainScreenAppear  8870358373313968633  1565206004    247
# 242332  PaymentScreenSuccessful  4718002964983105693  1565206005    247
# 242360  PaymentScreenSuccessful  2382591782303281935  1565206049    246
# 242362         CartScreenAppear  2382591782303281935  1565206049    246
# 242635         MainScreenAppear  4097782667445790512  1565206618    246
#
# [413 rows x 4 columns]

# %%
logs_exp_unique = logs_exp.drop_duplicates()

# %%
logs_exp_unique.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Добавьте столбец даты и времени, а также отдельный столбец дат.

# %%
logs_exp_unique['time'] = pd.to_datetime(logs_exp_unique['timestamp'], unit='s')
logs_exp_unique = logs_exp_unique.reset_index()
# Out:
# C:\Users\veron\AppData\Local\Temp\ipykernel_14740\2920370537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   logs_exp_unique['time'] = pd.to_datetime(logs_exp_unique['timestamp'], unit='s')

# %%
logs_exp_unique['date'] = logs_exp_unique['time'].astype('datetime64[D]')
logs_exp_unique = logs_exp_unique.reset_index()

# %%
logs_exp_unique.head(5)
# Out:
#    level_0  index               event_name              user_ID   timestamp  \
# 0        0      0         MainScreenAppear  4575588528974610257  1564029816
# 1        1      1         MainScreenAppear  7416695313311560658  1564053102
# 2        2      2  PaymentScreenSuccessful  3518123091307005509  1564054127
# 3        3      3         CartScreenAppear  3518123091307005509  1564054127
# 4        4      4  PaymentScreenSuccessful  6217807653094995999  1564055322
#
#    group                time       date
# 0    246 2019-07-25 04:43:36 2019-07-25
# 1    246 2019-07-25 11:11:42 2019-07-25
# 2    248 2019-07-25 11:28:47 2019-07-25
# 3    248 2019-07-25 11:28:47 2019-07-25
# 4    248 2019-07-25 11:48:42 2019-07-25

# %%
logs_exp_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243713 entries, 0 to 243712
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   level_0     243713 non-null  int64
#  1   index       243713 non-null  int64
#  2   event_name  243713 non-null  object
#  3   user_ID     243713 non-null  int64
#  4   timestamp   243713 non-null  int64
#  5   group       243713 non-null  int64
#  6   time        243713 non-null  datetime64[ns]
#  7   date        243713 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(5), object(1)
# memory usage: 14.9+ MB

# %%
logs_exp_unique.head(5)
# Out:
#    level_0  index               event_name              user_ID   timestamp  \
# 0        0      0         MainScreenAppear  4575588528974610257  1564029816
# 1        1      1         MainScreenAppear  7416695313311560658  1564053102
# 2        2      2  PaymentScreenSuccessful  3518123091307005509  1564054127
# 3        3      3         CartScreenAppear  3518123091307005509  1564054127
# 4        4      4  PaymentScreenSuccessful  6217807653094995999  1564055322
#
#    group                time       date
# 0    246 2019-07-25 04:43:36 2019-07-25
# 1    246 2019-07-25 11:11:42 2019-07-25
# 2    248 2019-07-25 11:28:47 2019-07-25
# 3    248 2019-07-25 11:28:47 2019-07-25
# 4    248 2019-07-25 11:48:42 2019-07-25

# %% [markdown]
# # Промежуточный вывод 2:
# После изучения общей информации о файле можно сделать вывод, что предоставленные данные выглядят правдоподобно. В файле нет пропусков, но есть дубликаты, которые удалила. Типы данных корректные.
#
# С файлом проделаны следующие действия:
# - В данных 244 126 строк, которые разделены на 4 столбца,
# - Столбцы переименованы: 'EventName' в 'event_name', 'DeviceIDHash' в 'user_ID', 'EventTimestamp' в 'timestamp', 'ExpId' в 'group',
# - В файл добавлены столбцы 'time'(даты и время) и 'date'(даты),
# - Т.к. доля дубликатов от исходных данных 1,69 %, удалила их.

# %% [markdown]
# ## Изучите и проверьте данные.
# ###  Сколько всего событий в логе.

# %%
count_event = logs_exp_unique['event_name'].count()
print('Всего событий в логе:', count_event)
# Out:
# Всего событий в логе: 243713

# %% [markdown]
# ### Сколько всего пользователей в логе.

# %%
nunique_user_ID = logs_exp_unique['user_ID'].nunique()
print('Всего пользователей в логе:', nunique_user_ID)
# Out:
# Всего пользователей в логе: 7551

# %% [markdown]
# ### Сколько в среднем событий приходится на пользователя.

# %%
logs_exp_unique.describe()
# Out:
#              level_0          index       user_ID     timestamp          group
# count  243713.000000  243713.000000  2.437130e+05  2.437130e+05  243713.000000
# mean   121856.000000  122079.103253  4.627963e+18  1.564914e+09     247.022161
# std     70354.027415   70474.421140  2.642723e+18  1.771388e+05       0.824420
# min         0.000000       0.000000  6.888747e+15  1.564030e+09     246.000000
# 25%     60928.000000   61059.000000  2.372212e+18  1.564757e+09     246.000000
# 50%    121856.000000  122097.000000  4.623192e+18  1.564919e+09     247.000000
# 75%    182784.000000  183115.000000  6.932517e+18  1.565075e+09     248.000000
# max    243712.000000  244125.000000  9.222603e+18  1.565213e+09     248.000000

# %%
mean_event = count_event / nunique_user_ID
print('В среднем на пользователя приходится событий:', round(mean_event, 2))
# Out:
# В среднем на пользователя приходится событий: 32.28

# %% [markdown]
# # Промежуточный вывод 3.3.:
#
# - Применив метод describe() видно, что распределение скошено влево (есть несколько аномальных пользователей),
# - В среднем на пользователя приходится событий: 32.28.

# %% [markdown]
# ### Данными за какой период вы располагаете.

# %%
max_date = max(logs_exp_unique['date'])
print('Максимальная дата:', max_date)
# Out:
# Максимальная дата: 2019-08-07 00:00:00

# %%
min_date = min(logs_exp_unique['date'])
print('Минимальная дата:', min_date)
# Out:
# Минимальная дата: 2019-07-25 00:00:00

# %% [markdown]
# # Промежуточный вывод 3.4.:
# Располагаю данными с '2019-07-25' по '2019-08-07'.

# %% [markdown]
# ### Изучите, как меняется количество данных.Постройте столбчатую диаграмму, которая отобразит количество событий в зависимости от времени в разрезе групп.

# %%
logs_exp_unique['date'] = pd.to_datetime(logs_exp_unique['date']).dt.date

logs_exp_unique_group = logs_exp_unique.pivot_table(
    index='date', 
    columns='group', 
    values='event_name', 
    aggfunc='count'
)

# Используем .plot() с kind='bar'
logs_exp_unique_group.plot(kind='bar', figsize=(10, 5))

plt.title('Диаграмма зависимости количества событий от времени в разрезе групп')
plt.xlabel('Дата', color='red')
plt.ylabel('Количество событий', color='green')
plt.show()

# %% [markdown]
# # Промежуточный вывод 3.5.:
# В результате анализа столбчатой диаграммы, которая отображает количество событий в зависимости от времени в разрезе групп, можно сказать:
# - до 01 августа 2019 года количество событий минимальное,
# - с 01 по 07 августа 2019 года количество событий варьируется от 10 000 до 14 000.
#
# Нельзя быть уверенным, что у нас одинаково полные данные за весь период. Технически в логи новых дней по некоторым пользователям могут «доезжать» события из прошлого — это может «перекашивать данные».

# %% [markdown]
# ###  Определите, с какого момента данные полные и отбросьте более старые. Данными за какой период времени вы располагаете на самом деле.

# %%
ax = logs_exp_unique['date'].hist(bins=50)
plt.title('Гистограмма по дате и времени')
plt.ylabel("Частота")
plt.xlabel("Дата")
plt.xticks(rotation=45) #для красоты
plt.show()

# %%
logs_exp_unique['date'] = pd.to_datetime(logs_exp_unique['date'], dayfirst=True)

# %%
logs_exp_unique_1 = logs_exp_unique[(logs_exp_unique['date'] > "2019-07-31")]
logs_exp_unique_1.head(5)
# Out:
#       level_0  index          event_name              user_ID   timestamp  \
# 2826     2826   2828            Tutorial  3737462046622621720  1564618048
# 2827     2827   2829    MainScreenAppear  3737462046622621720  1564618080
# 2828     2828   2830    MainScreenAppear  3737462046622621720  1564618135
# 2829     2829   2831  OffersScreenAppear  3737462046622621720  1564618138
# 2830     2830   2832    MainScreenAppear  1433840883824088890  1564618139
#
#       group                time       date
# 2826    246 2019-08-01 00:07:28 2019-08-01
# 2827    246 2019-08-01 00:08:00 2019-08-01
# 2828    246 2019-08-01 00:08:55 2019-08-01
# 2829    246 2019-08-01 00:08:58 2019-08-01
# 2830    247 2019-08-01 00:08:59 2019-08-01

# %% [markdown]
# # Промежуточный вывод 3.6.:
#
# Определила с помощью гистограммы по дате и количеству событий, что данные полные с 2019-08-01, т.к. видно, что событий ранее в разы меньше, чем в августе. Более ранние данные отбросила.
# Получается, что обладаю данными на самом деле за период времени  с '2019-08-01' по '2019-08-07'.

# %% [markdown]
# ### Много ли событий и пользователей вы потеряли, отбросив старые данные.

# %%
count_event_1 = logs_exp_unique_1['event_name'].count()
difference_count_event = count_event - count_event_1

print('Отбросив старые данные потеряли событий:', difference_count_event)
print('После отброшенных старых данных осталось событий:', count_event_1)
# Out:
# Отбросив старые данные потеряли событий: 2826
# После отброшенных старых данных осталось событий: 240887

# %%
nunique_user_ID_1 = logs_exp_unique_1['user_ID'].nunique()
difference_nunique_user_ID = nunique_user_ID - nunique_user_ID_1

print('Отбросив старые данные потеряли пользователей в количестве:', difference_nunique_user_ID)
print('После отброшенных старых данных осталось пользователей:', nunique_user_ID_1)
# Out:
# Отбросив старые данные потеряли пользователей в количестве: 17
# После отброшенных старых данных осталось пользователей: 7534

# %%
share_data = 1 - round(count_event_1/count_event, 2)
print('Доля, которую составляют отбрасываемые события от исходных данных', share_data)
# Out:
# Доля, которую составляют отбрасываемые события от исходных данных 0.010000000000000009

# %%
share_users = 1 - round(nunique_user_ID_1/nunique_user_ID, 3)
print('Доля, которую составляют отброшенные пользователи от исходного количества', share_users)
# Out:
# Доля, которую составляют отброшенные пользователи от исходного количества 0.0020000000000000018

# %% [markdown]
# # Промежуточный вывод 3.7.:
#
# В результате отбрасывания старых данных потеряны:
# - 796 событий (было - 243 713, стало - 242 917),
# - 9 пользователей (было - 7 551, стало - 7 542).
#
# Доли, которые составляют отброшенные данные от исходных данных:
# - Отбрасываемые события от исходных данных составляют 0.01 (т.е. 1 %),
# - Отброшенные пользователи от исходного количества 0.002 (т.е. 0,2 %).

# %% [markdown]
# ### Проверьте, что у вас есть пользователи из всех трёх экспериментальных групп.

# %%
user_group = logs_exp_unique.groupby(['group']).agg({'user_ID': 'nunique'})
user_group
# Out:
#        user_ID
# group
# 246       2489
# 247       2520
# 248       2542

# %% [markdown]
# # Промежуточный вывод 3.8.:
#
# Проверила и убедилась, что после отбрасывания старых данных остались пользователи из всех трёх экспериментальных групп^
# - 246 группа - 2 489 пользователей,
# - 247 группа - 2 520 пользователей,
# - 248 группа - 2 542 пользователя.

# %% [markdown]
# ## Изучите воронку событий
#
# ### Посмотрите, какие события есть в логах, как часто они встречаются. Отсортируйте события по частоте.

# %%
logs_exp_unique['event_name'].unique()
# Out:
# array(['MainScreenAppear', 'PaymentScreenSuccessful', 'CartScreenAppear',
#        'OffersScreenAppear', 'Tutorial'], dtype=object)

# %%
logs_exp_unique.groupby('event_name')['event_name'].count().sort_values(ascending=False)
# Out:
# event_name
# MainScreenAppear           119101
# OffersScreenAppear          46808
# CartScreenAppear            42668
# PaymentScreenSuccessful     34118
# Tutorial                     1018
# Name: event_name, dtype: int64

# %% [markdown]
# # Промежуточный вывод 4.1.:
# В логах есть следующие события:
# - MainScreenAppear (частота: 119 101),
# - OffersScreenAppear (частота: 46 808),
# - CartScreenAppear  (частота: 42 668),
# - PaymentScreenSuccessful  (частота: 34 118),
# - Tutorial (частота: 1 018).

# %% [markdown]
# ### Посчитайте, сколько пользователей совершали каждое из этих событий.

# %%
user_event = logs_exp_unique.groupby(['event_name']).agg({'user_ID': 'nunique'})
user_event
# Out:
#                          user_ID
# event_name
# CartScreenAppear            3749
# MainScreenAppear            7439
# OffersScreenAppear          4613
# PaymentScreenSuccessful     3547
# Tutorial                     847

# %% [markdown]
# # Промежуточный вывод 4.2.:
# Посчитала, сколько пользователей совершили каждое из событий. :
# - MainScreenAppear (7 439 пользователей),
# - OffersScreenAppear (4 613 пользователей),
# - CartScreenAppear  (3 749 пользователей),
# - PaymentScreenSuccessful  (3 547 пользователей),
# - Tutorial (847 пользователей).

# %% [markdown]
# ### Отсортируйте события по числу пользователей.

# %%
logs1 = logs_exp_unique.groupby(['event_name']).agg({'user_ID': 'nunique'}).sort_values(by='user_ID', ascending=False)
logs1
# Out:
#                          user_ID
# event_name
# MainScreenAppear            7439
# OffersScreenAppear          4613
# CartScreenAppear            3749
# PaymentScreenSuccessful     3547
# Tutorial                     847

# %% [markdown]
# ### Посчитайте долю пользователей, которые хоть раз совершали событие.

# %%
logs_exp_unique_1 = logs_exp_unique.loc[logs_exp_unique.event_name != 'Tutorial']
logs_exp_unique_1
# Out:
#         level_0   index               event_name              user_ID  \
# 0             0       0         MainScreenAppear  4575588528974610257
# 1             1       1         MainScreenAppear  7416695313311560658
# 2             2       2  PaymentScreenSuccessful  3518123091307005509
# 3             3       3         CartScreenAppear  3518123091307005509
# 4             4       4  PaymentScreenSuccessful  6217807653094995999
# ...         ...     ...                      ...                  ...
# 243708   243708  244121         MainScreenAppear  4599628364049201812
# 243709   243709  244122         MainScreenAppear  5849806612437486590
# 243710   243710  244123         MainScreenAppear  5746969938801999050
# 243711   243711  244124         MainScreenAppear  5746969938801999050
# 243712   243712  244125       OffersScreenAppear  5746969938801999050
#
#          timestamp  group                time       date
# 0       1564029816    246 2019-07-25 04:43:36 2019-07-25
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Да, верно событие `Tutorial` опционально и не является частью воронки событий пользователей.
# </div>

# %%
logs_exp_unique_2 = logs_exp_unique_1.groupby(['event_name']).agg({'user_ID': 'nunique'}).sort_values(by='user_ID', ascending=False)

logs_exp_unique_2
# Out:
#                          user_ID
# event_name
# MainScreenAppear            7439
# OffersScreenAppear          4613
# CartScreenAppear            3749
# PaymentScreenSuccessful     3547

# %%
user_nunique = logs_exp_unique.agg({'user_ID': 'nunique'})
print('Пользователей всего', user_nunique['user_ID'])
# Out:
# Пользователей всего 7551

# %%
logs_exp_unique_2['%'] = round(logs_exp_unique_2['user_ID'] / user_nunique['user_ID'], 2)
logs_exp_unique_2
# Out:
#                          user_ID     %
# event_name
# MainScreenAppear            7439  0.99
# OffersScreenAppear          4613  0.61
# CartScreenAppear            3749  0.50
# PaymentScreenSuccessful     3547  0.47

# %% [markdown]
# # Промежуточный итог 4.4.:
# Посчитала для каждого события долю пользователей от всех:
# - MainScreenAppear - 99 %,
# - OffersScreenAppear - 61 %,
# - CartScreenAppear	- 50 %,
# - PaymentScreenSuccessful	- 47 %.

# %% [markdown]
# ### Предположите, в каком порядке происходят события. Все ли они выстраиваются в последовательную цепочку? Их не нужно учитывать при расчёте воронки.

# %% [markdown]
# # Промежуточный итог 4.5.:
# Предполагаю, что события происходят в следующем порядке:
# MainScreenAppear - появляется главный экран,
# OffersScreenAppear - появляется экран предложений,
# CartScreenAppear - появляется экран корзины,
# PaymentScreenSuccessful - экран оплаты успешен.
#
# Событие Tutorial - обучение, на мой взгляд, не встраивается в последовательную цепочку и его не нужно учитывать при расчёте воронки.

# %% [markdown]
# ### По воронке событий посчитайте, какая доля пользователей проходит на следующий шаг воронки (от числа пользователей на предыдущем). То есть для последовательности событий A → B → C посчитайте отношение числа пользователей с событием B к количеству пользователей с событием A, а также отношение числа пользователей с событием C к количеству пользователей с событием B.
# На каком шаге теряете больше всего пользователей?
# Какая доля пользователей доходит от первого события до оплаты?

# %%
logs_exp_unique_2['%_prev_step'] = round(1 + logs_exp_unique_2['user_ID'].pct_change(), 2)
logs_exp_unique_2
# Out:
#                          user_ID     %  %_prev_step
# event_name
# MainScreenAppear            7439  0.99          NaN
# OffersScreenAppear          4613  0.61         0.62
# CartScreenAppear            3749  0.50         0.81
# PaymentScreenSuccessful     3547  0.47         0.95

# %% [markdown]
# # Промежуточный итог 4.6.:
# Посчитала долю пользователей, проходящих на следующий шаг воронки:
# - OffersScreenAppear - 62 %,
# - CartScreenAppear - 81 %,
# - PaymentScreenSuccessful	95 %.
#
# Больше всего теряется пользователей на шаге от MainScreenAppear к OffersScreenAppear. Не проходят дальше 48 % пользователей. В связи с этим нужно лучше прорабатывать механику, чтобы пользователи переходили к OffersScreenAppear.

# %% [markdown]
# ## Изучите результаты эксперимента
#
# ### Сколько пользователей в каждой экспериментальной группе?

# %%
logs_exp_unique_3 = logs_exp_unique_1.groupby(['group']).agg({'user_ID': 'nunique'})
logs_exp_unique_3
# Out:
#        user_ID
# group
# 246       2488
# 247       2519
# 248       2540

# %%
logs_exp_unique_3['fraction'] = round(logs_exp_unique_3['user_ID'] / user_nunique['user_ID'], 3)
logs_exp_unique_3
# Out:
#        user_ID  fraction
# group
# 246       2488     0.329
# 247       2519     0.334
# 248       2540     0.336

# %% [markdown]
# # Промежуточный вывод 5.1.:
#
# Определила сколько пользователей в каждой экспериментальной группе:
# - группа 246 - 2 488,
# - группа 247 - 2 519,
# - группа 248 - 2 540.
#
# Рассчитала доли числа пользователей в группах к общему числу пользователей:
# - группа 246 - 0.329 (т.е. 32,9 %),
# - группа 247 - 0.334 (т.е. 33,4 %),
# - группа 248 - 0.336 (т.е. 33,6 %).

# %% [markdown]
# ### Есть 2 контрольные группы для А/А-эксперимента, чтобы проверить корректность всех механизмов и расчётов. Проверьте, находят ли статистические критерии разницу между выборками 246 и 247.
#
# # Гипотезы:
# H0 - Статистически значимых различий в долях количества событий на пользователя между группами нет.
#
# H1 - Статистически значимые различия в долях количества событий на пользователя между группами есть.

# %%
logs_exp_unique_1.head(5)
# Out:
#    level_0  index               event_name              user_ID   timestamp  \
# 0        0      0         MainScreenAppear  4575588528974610257  1564029816
# 1        1      1         MainScreenAppear  7416695313311560658  1564053102
# 2        2      2  PaymentScreenSuccessful  3518123091307005509  1564054127
# 3        3      3         CartScreenAppear  3518123091307005509  1564054127
# 4        4      4  PaymentScreenSuccessful  6217807653094995999  1564055322
#
#    group                time       date
# 0    246 2019-07-25 04:43:36 2019-07-25
# 1    246 2019-07-25 11:11:42 2019-07-25
# 2    248 2019-07-25 11:28:47 2019-07-25
# 3    248 2019-07-25 11:28:47 2019-07-25
# 4    248 2019-07-25 11:48:42 2019-07-25

# %%
exp_246 = logs_exp_unique_1[logs_exp_unique_1['group'] == 246]
exp_247 = logs_exp_unique_1[logs_exp_unique_1['group'] == 247]

# Группируем по пользователям и считаем количество событий для каждого
user_events_246 = exp_246.groupby('user_ID')['event_name'].count()
user_events_247 = exp_247.groupby('user_ID')['event_name'].count()

# Проводим t-тест
t_stat, p_value = st.ttest_ind(user_events_246, user_events_247, equal_var=False)  # (не предполагаем равенство дисперсий)

alpha = 0.05
if p_value < alpha:
    print(f"Отвергаем нулевую гипотезу: p-value = {p_value:.5f}")
else:
    print(f"Не отвергаем нулевую гипотезу: p-value = {p_value:.5f}")
# Out:
# Не отвергаем нулевую гипотезу: p-value = 0.45298

# %%
logs_exp_unique_group_246_247 = logs_exp_unique.loc[logs_exp_unique.group != 248]
logs_exp_unique_group_248 = logs_exp_unique.loc[logs_exp_unique.group == 248]

# %%
merged_df = pd.merge(logs_exp_unique_group_246_247, logs_exp_unique_group_248, on='user_ID', how='inner')
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   level_0_x     0 non-null      int64
#  1   index_x       0 non-null      int64
#  2   event_name_x  0 non-null      object
#  3   user_ID       0 non-null      int64
#  4   timestamp_x   0 non-null      int64
#  5   group_x       0 non-null      int64
#  6   time_x        0 non-null      datetime64[ns]
#  7   date_x        0 non-null      datetime64[ns]
#  8   level_0_y     0 non-null      int64
#  9   index_y       0 non-null      int64
#  10  event_name_y  0 non-null      object
#  11  timestamp_y   0 non-null      int64
#  12  group_y       0 non-null      int64
#  13  time_y        0 non-null      datetime64[ns]
#  14  date_y        0 non-null      datetime64[ns]
# dtypes: datetime64[ns](4), int64(9), object(2)
# memory usage: 0.0+ bytes

# %% [markdown]
# # Промежуточный вывод 5.2.:
# В двух контрольных группах (246 и 247) статистически значимых различий в долях каждого события от всех пользователей между группами нет.
#
# С помощью merge() убедилась в том, что при проведении АА / ААВ тестов, в группах не будут пользователи, которые участвуют одновременно в двух группах.

# %% [markdown]
# ### Выберите самое популярное событие.

# %%
logs2 = logs_exp_unique_1.groupby(['event_name']).agg({'user_ID': 'count'}).sort_values(by='user_ID', ascending=False)
logs2
# Out:
#                          user_ID
# event_name
# MainScreenAppear          119101
# OffersScreenAppear         46808
# CartScreenAppear           42668
# PaymentScreenSuccessful    34118

# %% [markdown]
# # Промежуточный вывод 5.3.:
#
# Самое популярное событие: MainScreenAppear	(произошло 119 101 раз).

# %% [markdown]
# ### Посчитайте число пользователей, совершивших это событие в каждой из контрольных групп.

# %%
logs_exp_unique_group_246 = logs_exp_unique_1.loc[logs_exp_unique_1.group == 246]
logs_exp_unique_group_246.head(5)
# Out:
#    level_0  index          event_name              user_ID   timestamp  group  \
# 0        0      0    MainScreenAppear  4575588528974610257  1564029816    246
# 1        1      1    MainScreenAppear  7416695313311560658  1564053102    246
# 6        6      6  OffersScreenAppear  8351860793733343758  1564066242    246
# 7        7      7    MainScreenAppear  5682100281902512875  1564085677    246
# 9        9      9    MainScreenAppear  5407636962369102641  1564112112    246
#
#                  time       date
# 0 2019-07-25 04:43:36 2019-07-25
# 1 2019-07-25 11:11:42 2019-07-25
# 6 2019-07-25 14:50:42 2019-07-25
# 7 2019-07-25 20:14:37 2019-07-25
# 9 2019-07-26 03:35:12 2019-07-26

# %%
logs3 = logs_exp_unique_group_246.groupby(['event_name']).agg({'user_ID': 'nunique'}).sort_values(by='user_ID', ascending=False)
logs3
# Out:
#                          user_ID
# event_name
# MainScreenAppear            2456
# OffersScreenAppear          1545
# CartScreenAppear            1270
# PaymentScreenSuccessful     1202

# %%
logs_exp_unique_group_247 = logs_exp_unique_1.loc[logs_exp_unique_1.group == 247]
logs_exp_unique_group_247.head(5)
# Out:
#     level_0  index        event_name              user_ID   timestamp  group  \
# 8         8      8  MainScreenAppear  1850981295691852772  1564086702    247
# 10       10     10  MainScreenAppear   948465712512390382  1564119214    247
# 13       13     13  MainScreenAppear  2140904690380565988  1564125732    247
# 16       16     16  MainScreenAppear  5839517684026830712  1564141421    247
# 18       18     18  CartScreenAppear  2575393697599976818  1564148945    247
#
#                   time       date
# 8  2019-07-25 20:31:42 2019-07-25
# 10 2019-07-26 05:33:34 2019-07-26
# 13 2019-07-26 07:22:12 2019-07-26
# 16 2019-07-26 11:43:41 2019-07-26
# 18 2019-07-26 13:49:05 2019-07-26

# %%
logs4 = logs_exp_unique_group_247.groupby(['event_name']).agg({'user_ID': 'nunique'}).sort_values(by='user_ID', ascending=False)
logs4
# Out:
#                          user_ID
# event_name
# MainScreenAppear            2482
# OffersScreenAppear          1530
# CartScreenAppear            1240
# PaymentScreenSuccessful     1160

# %%
logs_exp_unique_group_248 = logs_exp_unique_1.loc[logs_exp_unique_1.group == 248]
logs_exp_unique_group_248.head(5)
# Out:
#     level_0  index               event_name              user_ID   timestamp  \
# 2         2      2  PaymentScreenSuccessful  3518123091307005509  1564054127
# 3         3      3         CartScreenAppear  3518123091307005509  1564054127
# 4         4      4  PaymentScreenSuccessful  6217807653094995999  1564055322
# 5         5      5         CartScreenAppear  6217807653094995999  1564055323
# 11       11     11         MainScreenAppear  2547684315586332355  1564123826
#
#     group                time       date
# 2     248 2019-07-25 11:28:47 2019-07-25
# 3     248 2019-07-25 11:28:47 2019-07-25
# 4     248 2019-07-25 11:48:42 2019-07-25
# 5     248 2019-07-25 11:48:43 2019-07-25
# 11    248 2019-07-26 06:50:26 2019-07-26

# %%
logs5 = logs_exp_unique_group_248.groupby(['event_name']).agg({'user_ID': 'nunique'}).sort_values(by='user_ID', ascending=False)
logs5
# Out:
#                          user_ID
# event_name
# MainScreenAppear            2501
# OffersScreenAppear          1538
# CartScreenAppear            1239
# PaymentScreenSuccessful     1185

# %% [markdown]
# # Промежуточный вывод 5.4.:
# Посчитала число пользователей, совершивших самое популярное событие 'MainScreenAppear' в каждой из контрольных групп:
# - 246 группа - 2 456,
# - 247 группа - 2 482,
# - 248 группа - 2 501.

# %% [markdown]
# ### Посчитайте долю пользователей, совершивших это событие.

# %%
user_ID_count = logs_exp_unique_1['user_ID'].nunique()
print('Общее количество пользователей', user_ID_count)
# Out:
# Общее количество пользователей 7547

# %%
logs_exp_unique_3
# Out:
#        user_ID  fraction
# group
# 246       2488     0.329
# 247       2519     0.334
# 248       2540     0.336

# %%
MainScreenAppear_246 = round(2456 / 2488, 2)
print('Доля пользователей 246 группы, совершивших это событие, от общего количества пользователей', MainScreenAppear_246)
# Out:
# Доля пользователей 246 группы, совершивших это событие, от общего количества пользователей 0.99

# %%
MainScreenAppear_247 = round(2482 / 2519, 2)
print('Доля пользователей 247 группы, совершивших это событие, от общего количества пользователей', MainScreenAppear_247)
# Out:
# Доля пользователей 247 группы, совершивших это событие, от общего количества пользователей 0.99

# %%
MainScreenAppear_248 = round(2501 / 2540, 2)
print('Доля пользователей 248 группы, совершивших это событие, от общего количества пользователей', MainScreenAppear_248)
# Out:
# Доля пользователей 248 группы, совершивших это событие, от общего количества пользователей 0.98

# %% [markdown]
# # Промежуточный вывод 5.5.:
# Посчитала долю пользователей, совершивших событие 'MainScreenAppear':
# - 246 группа - 0.99,
# - 247 группа - 0.99,
# - 248 группа - 0.98.

# %% [markdown]
# ### Проверьте, будет ли отличие между группами статистически достоверным. Проделайте то же самое для всех других событий (удобно обернуть проверку в отдельную функцию). Можно ли сказать, что разбиение на группы работает корректно?

# %%
exp_MainScreenAppear_246 = exp_246.loc[exp_246.event_name == 'MainScreenAppear']
exp_MainScreenAppear_247 = exp_247.loc[exp_247.event_name == 'MainScreenAppear']

user_MainScreenAppear_246 = exp_MainScreenAppear_246['user_ID'].nunique()
user_MainScreenAppear_247 = exp_MainScreenAppear_247['user_ID'].nunique()

exp_OffersScreenAppear_246 = exp_246.loc[exp_246.event_name == 'OffersScreenAppear']
exp_OffersScreenAppear_247 = exp_247.loc[exp_247.event_name == 'OffersScreenAppear']

user_OffersScreenAppear_246 = exp_OffersScreenAppear_246['user_ID'].nunique()
user_OffersScreenAppear_247 = exp_OffersScreenAppear_247['user_ID'].nunique()

exp_CartScreenAppear_246 = exp_246.loc[exp_246.event_name == 'CartScreenAppear']
exp_CartScreenAppear_247 = exp_247.loc[exp_247.event_name == 'CartScreenAppear']

user_CartScreenAppear_246 = exp_CartScreenAppear_246['user_ID'].nunique()
user_CartScreenAppear_247 = exp_CartScreenAppear_247['user_ID'].nunique()

exp_PaymentScreenSuccessful_246 = exp_246.loc[exp_246.event_name == 'PaymentScreenSuccessful']
exp_PaymentScreenSuccessful_247 = exp_247.loc[exp_247.event_name == 'PaymentScreenSuccessful']

user_PaymentScreenSuccessful_246 = exp_PaymentScreenSuccessful_246['user_ID'].nunique()
user_PaymentScreenSuccessful_247 = exp_PaymentScreenSuccessful_247['user_ID'].nunique()

nobs_246 = exp_246['user_ID'].nunique()    # Число уникальных пользователей в 246
nobs_247 = exp_247['user_ID'].nunique()    # Число уникальных пользователей в 247

# %%
# Проверяю, будет ли отличия между группами 246 и 247 по событиям

alpha = .05 # критический уровень статистической значимости

# %%
successes_MainScreenAppear = np.array([user_MainScreenAppear_246, user_MainScreenAppear_247])
successes_OffersScreenAppear = np.array([user_OffersScreenAppear_246, user_OffersScreenAppear_247])
successes_CartScreenAppear = np.array([user_CartScreenAppear_246, user_CartScreenAppear_247])
successes_PaymentScreenSuccessful = np.array([user_PaymentScreenSuccessful_246, user_PaymentScreenSuccessful_247])
trials = np.array([nobs_246, nobs_247])

# объявляем функцию difference_246_247 с двумя параметрами: # successes и trials
def difference_246_247(successes, trials): # заголовок функции
    # пропорция успехов в 246 группе:
    p246 = successes[0]/trials[0]

    # пропорция успехов в 247 группе:
    p247 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference_246_247 = p246 - p247 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference_246_247 / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  
    
    p_value = (1 - distr.cdf(abs(z_value))) * 2
    print('p-значение: ', p_value)
   
    if p_value < alpha:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    ) 

print('При проверке будет ли отличие между группами 246 и 247 по событию MainScreenAppear получаем')
MainScreenAppear_event =  difference_246_247(successes_MainScreenAppear, trials)

print('При проверке будет ли отличие между группами 246 и 247 по событию OffersScreenAppear получаем')
OffersScreenAppear =  difference_246_247(successes_OffersScreenAppear, trials)

print('При проверке будет ли отличие между группами 246 и 247 по событию CartScreenAppear получаем')
CartScreenAppear =  difference_246_247(successes_CartScreenAppear, trials)

print('При проверке будет ли отличие между группами 246 и 247 по событию PaymentScreenSuccessful получаем')
PaymentScreenSuccessful =  difference_246_247(successes_PaymentScreenSuccessful, trials)
# Out:
# При проверке будет ли отличие между группами 246 и 247 по событию MainScreenAppear получаем
# p-значение:  0.5793437006065798
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 247 по событию OffersScreenAppear получаем
# p-значение:  0.32306072283730236
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 247 по событию CartScreenAppear получаем
# p-значение:  0.19802427060680183
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 247 по событию PaymentScreenSuccessful получаем
# p-значение:  0.108925858137356
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными

# %% [markdown]
# # Промежуточный вывод 5.6.:
# После проведения вычислений видно, что нет оснований считать доли разными, т.е. нельзя говорить о статистически значимом различии между группами 246 и 247. Можно сказать, что разбиение на группы работает корректно.

# %% [markdown]
# ### Аналогично поступите с группой с изменённым шрифтом. Сравните результаты с каждой из контрольных групп в отдельности по каждому событию.
# #### Сравнение 246 и 248 групп.

# %%
# Проверяю, будет ли отличие между группами 246 и 248 по событиям
exp_248 = logs_exp_unique_1[logs_exp_unique_1['group'] == 248]
nobs_248 = exp_248['user_ID'].nunique()

alpha = .05 # критический уровень статистической значимости

# %%
exp_MainScreenAppear_248 = exp_248.loc[exp_248.event_name == 'MainScreenAppear']
user_MainScreenAppear_248 = exp_MainScreenAppear_248['user_ID'].nunique()

exp_OffersScreenAppear_248 = exp_248.loc[exp_248.event_name == 'OffersScreenAppear']
user_OffersScreenAppear_248 = exp_OffersScreenAppear_248['user_ID'].nunique()

exp_CartScreenAppear_248 = exp_248.loc[exp_248.event_name == 'CartScreenAppear']
user_CartScreenAppear_248 = exp_CartScreenAppear_248['user_ID'].nunique()

exp_PaymentScreenSuccessful_248 = exp_248.loc[exp_248.event_name == 'PaymentScreenSuccessful']
user_PaymentScreenSuccessful_248 = exp_PaymentScreenSuccessful_248['user_ID'].nunique()

# %%
successes_MainScreenAppear_2 = np.array([user_MainScreenAppear_246, user_MainScreenAppear_248])
successes_OffersScreenAppear_2 = np.array([user_OffersScreenAppear_246, user_OffersScreenAppear_248])
successes_CartScreenAppear_2 = np.array([user_CartScreenAppear_246, user_CartScreenAppear_248])
successes_PaymentScreenSuccessful_2 = np.array([user_PaymentScreenSuccessful_246, user_PaymentScreenSuccessful_248])
trials_2 = np.array([nobs_246, nobs_248])

# объявляем функцию difference_246_248 с двумя параметрами: # successes и trials
def difference_246_248(successes, trials): # заголовок функции
    # пропорция успехов в 246 группе:
    p246 = successes[0]/trials[0]

    # пропорция успехов в 248 группе:
    p248 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference_246_248 = p246 - p248 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference_246_248 / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  
    
    p_value = (1 - distr.cdf(abs(z_value))) * 2
    print('p-значение: ', p_value)
   
    if p_value < alpha:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    )

# %%
print('При проверке будет ли отличие между группами 246 и 248 по событию MainScreenAppear получаем')
MainScreenAppear_event =  difference_246_248(successes_MainScreenAppear_2, trials_2)

print('При проверке будет ли отличие между группами 246 и 248 по событию OffersScreenAppear получаем')
OffersScreenAppear =  difference_246_248(successes_OffersScreenAppear_2, trials_2)

print('При проверке будет ли отличие между группами 246 и 248 по событию CartScreenAppear получаем')
CartScreenAppear =  difference_246_248(successes_CartScreenAppear_2, trials_2)

print('При проверке будет ли отличие между группами 246 и 248 по событию PaymentScreenSuccessful получаем')
PaymentScreenSuccessful =  difference_246_248(successes_PaymentScreenSuccessful_2, trials_2)
# Out:
# При проверке будет ли отличие между группами 246 и 248 по событию MainScreenAppear получаем
# p-значение:  0.4538875165311982
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 248 по событию OffersScreenAppear получаем
# p-значение:  0.2601500947498627
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 248 по событию CartScreenAppear получаем
# p-значение:  0.1081995040532513
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 248 по событию PaymentScreenSuccessful получаем
# p-значение:  0.239054894032515
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными

# %% [markdown]
# # Промежуточный вывод 5.7.1.:
# После проведения вычислений видно, что нет оснований считать доли разными, т.е. нельзя говорить о статистически значимом различии между группами 246 и 248. Можно сказать, что разбиение на группы работает корректно.

# %% [markdown]
# #### Сравнение 247 и 248 групп.

# %%
# Проверяю, будет ли отличие между группами 247 и 248 по событиям
alpha = .05 # критический уровень статистической значимости

successes_MainScreenAppear_3 = np.array([user_MainScreenAppear_247, user_MainScreenAppear_248])
successes_OffersScreenAppear_3 = np.array([user_OffersScreenAppear_247, user_OffersScreenAppear_248])
successes_CartScreenAppear_3 = np.array([user_CartScreenAppear_247, user_CartScreenAppear_248])
successes_PaymentScreenSuccessful_3 = np.array([user_PaymentScreenSuccessful_247, user_PaymentScreenSuccessful_248])
trials_3 = np.array([nobs_247, nobs_248])

# объявляем функцию difference_247_248 с двумя параметрами: # successes и trials
def difference_247_248(successes, trials): # заголовок функции
    # пропорция успехов в 247 группе:
    p247 = successes[0]/trials[0]

    # пропорция успехов в 248 группе:
    p248 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference_247_248 = p247 - p248 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference_247_248 / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  
    
    p_value = (1 - distr.cdf(abs(z_value))) * 2
    print('p-значение: ', p_value)
   
    if p_value < alpha:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    )

# %%
print('При проверке будет ли отличие между группами 247 и 248 по событию MainScreenAppear получаем')
MainScreenAppear_event =  difference_247_248(successes_MainScreenAppear_3, trials_3)

print('При проверке будет ли отличие между группами 247 и 248 по событию OffersScreenAppear получаем')
OffersScreenAppear =  difference_247_248(successes_OffersScreenAppear_3, trials_3)

print('При проверке будет ли отличие между группами 247 и 248 по событию CartScreenAppear получаем')
CartScreenAppear =  difference_247_248(successes_CartScreenAppear_3, trials_3)

print('При проверке будет ли отличие между группами 247 и 248 по событию PaymentScreenSuccessful получаем')
PaymentScreenSuccessful =  difference_247_248(successes_PaymentScreenSuccessful_3, trials_3)
# Out:
# При проверке будет ли отличие между группами 247 и 248 по событию MainScreenAppear получаем
# p-значение:  0.8456296578773543
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 247 и 248 по событию OffersScreenAppear получаем
# p-значение:  0.8916023466886049
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 247 и 248 по событию CartScreenAppear получаем
# p-значение:  0.7508350927093224
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 247 и 248 по событию PaymentScreenSuccessful получаем
# p-значение:  0.6668983315395216
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными

# %% [markdown]
# # Промежуточный вывод 5.7.2.:
#
# После проведения вычислений видно, что нет оснований считать доли разными, т.е. нельзя говорить о статистически значимом различии между группами 247 и 248. Можно сказать, что разбиение на группы работает корректно.

# %% [markdown]
# ### Сравните результаты с объединённой контрольной группой. Какие выводы из эксперимента можно сделать?

# %%
nobs_246_247 = nobs_246 + nobs_247

user_MainScreenAppear_246_247 = user_MainScreenAppear_246 + user_MainScreenAppear_247

user_OffersScreenAppear_246_247 = user_OffersScreenAppear_246 + user_OffersScreenAppear_247

user_CartScreenAppear_246_247 = user_CartScreenAppear_246 + user_CartScreenAppear_247

user_PaymentScreenSuccessful_246_247 = user_PaymentScreenSuccessful_246 + user_PaymentScreenSuccessful_247

# %%
# Проверяю, будет ли отличие между между объединенной группой 246 и 247 с экспериментальной группой 248 по событиям
alpha = .05 # критический уровень статистической значимости

successes_MainScreenAppear_4 = np.array([user_MainScreenAppear_246_247, user_MainScreenAppear_248])
successes_OffersScreenAppear_4 = np.array([user_OffersScreenAppear_246_247, user_OffersScreenAppear_248])
successes_CartScreenAppear_4 = np.array([user_CartScreenAppear_246_247, user_CartScreenAppear_248])
successes_PaymentScreenSuccessful_4 = np.array([user_PaymentScreenSuccessful_246_247, user_PaymentScreenSuccessful_248])
trials_4 = np.array([nobs_246_247, nobs_248])

# объявляем функцию difference_247_248 с двумя параметрами: # successes и trials
def difference_246_247_248(successes, trials): # заголовок функции
    # пропорция успехов в 246 и 247 группах:
    p246_247 = successes[0]/trials[0]

    # пропорция успехов в 248 группе:
    p248 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference_246_247_248 = p246_247 - p248 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference_246_247_248 / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  
    
    p_value = (1 - distr.cdf(abs(z_value))) * 2
    print('p-значение: ', p_value)
   
    if p_value < alpha:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    )

# %%
print('При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию MainScreenAppear получаем')
MainScreenAppear_event =  difference_246_247_248(successes_MainScreenAppear_4, trials_4)

print('При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию OffersScreenAppear получаем')
OffersScreenAppear =  difference_246_247_248(successes_OffersScreenAppear_4, trials_4)

print('При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию CartScreenAppear получаем')
CartScreenAppear =  difference_246_247_248(successes_CartScreenAppear_4, trials_4)

print('При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию PaymentScreenSuccessful получаем')
PaymentScreenSuccessful =  difference_246_247_248(successes_PaymentScreenSuccessful_4, trials_4)
# Out:
# При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию MainScreenAppear получаем
# p-значение:  0.5865055483330501
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию OffersScreenAppear получаем
# p-значение:  0.4674653325203759
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию CartScreenAppear получаем
# p-значение:  0.2675917289544225
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию PaymentScreenSuccessful получаем
# p-значение:  0.668624761940358
# ...

# %% [markdown]
# # Промежуточный вывод 5.8.:
# Исследую результаты ААВ эксперимента.
# Объединила данные 246 и 247 групп в одну и сравниваю получившийся датафрейм с данными 248 группы.
#
# После проведения вычислений видно, что нет оснований считать доли разными, т.е. нельзя говорить о статистически значимом различии между  объединенной группой 246 и 247 с экспериментальной группой 248. Можно сказать, что разбиение на группы работает корректно.

# %% [markdown]
# ### Посчитайте, сколько проверок статистических гипотез вы сделали.

# %%
# Считаю количество проверок статистических гипотез (сравнивала при каждой проверке 4 события)
count_examination = 4 * 4
print('Сделано следующее количество проверок статистических гипотез:', count_examination)
# Out:
# Сделано следующее количество проверок статистических гипотез: 16

# %% [markdown]
# ### Какой уровень значимости вы выбрали при проверке статистических гипотез выше?  При уровне значимости 0.1 в 10% случаев можно ошибочно отклонить нулевую гипотезу при условии, что она верна. Какой уровень значимости стоит применить? Если вы хотите изменить его, проделайте предыдущие пункты и проверьте свои выводы.

# %%
# Делаю поправку на множественное тестирование (поправка Бонферрони)
alpha_1 = alpha / 16
print('Исправленный уровень значимости:', alpha_1)
# Out:
# Исправленный уровень значимости: 0.003125

# %%
# Проверяю, будет ли отличия между группами 246 и 247 по событиям

# объявляем функцию difference_246_247 с двумя параметрами: # successes и trials
def difference_246_247(successes, trials): # заголовок функции
    # пропорция успехов в 246 группе:
    p246 = successes[0]/trials[0]

    # пропорция успехов в 247 группе:
    p247 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference_246_247 = p246 - p247 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference_246_247 / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  
    
    p_value = (1 - distr.cdf(abs(z_value))) * 2
    print('p-значение: ', p_value)
   
    if p_value < alpha_1:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    ) 

print('При проверке будет ли отличие между группами 246 и 247 по событию MainScreenAppear получаем')
MainScreenAppear_event =  difference_246_247(successes_MainScreenAppear, trials)

print('При проверке будет ли отличие между группами 246 и 247 по событию OffersScreenAppear получаем')
OffersScreenAppear =  difference_246_247(successes_OffersScreenAppear, trials)

print('При проверке будет ли отличие между группами 246 и 247 по событию CartScreenAppear получаем')
CartScreenAppear =  difference_246_247(successes_CartScreenAppear, trials)

print('При проверке будет ли отличие между группами 246 и 247 по событию PaymentScreenSuccessful получаем')
PaymentScreenSuccessful =  difference_246_247(successes_PaymentScreenSuccessful, trials)
# Out:
# При проверке будет ли отличие между группами 246 и 247 по событию MainScreenAppear получаем
# p-значение:  0.5793437006065798
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 247 по событию OffersScreenAppear получаем
# p-значение:  0.32306072283730236
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 247 по событию CartScreenAppear получаем
# p-значение:  0.19802427060680183
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 247 по событию PaymentScreenSuccessful получаем
# p-значение:  0.108925858137356
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными

# %%
# Проверяю, будет ли отличия между группами 246 и 248 по событиям

# объявляем функцию difference_246_248 с двумя параметрами: # successes и trials
def difference_246_248(successes, trials): # заголовок функции
    # пропорция успехов в 246 группе:
    p246 = successes[0]/trials[0]

    # пропорция успехов в 248 группе:
    p248 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference_246_248 = p246 - p248 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference_246_248 / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  
    
    p_value = (1 - distr.cdf(abs(z_value))) * 2
    print('p-значение: ', p_value)
   
    if p_value < alpha_1:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    ) 

        print('При проверке будет ли отличие между группами 246 и 248 по событию MainScreenAppear получаем')
MainScreenAppear_event =  difference_246_248(successes_MainScreenAppear_2, trials_2)

print('При проверке будет ли отличие между группами 246 и 248 по событию OffersScreenAppear получаем')
OffersScreenAppear =  difference_246_248(successes_OffersScreenAppear_2, trials_2)

print('При проверке будет ли отличие между группами 246 и 248 по событию CartScreenAppear получаем')
CartScreenAppear =  difference_246_248(successes_CartScreenAppear_2, trials_2)

print('При проверке будет ли отличие между группами 246 и 248 по событию PaymentScreenSuccessful получаем')
PaymentScreenSuccessful =  difference_246_248(successes_PaymentScreenSuccessful_2, trials_2)
# Out:
# p-значение:  0.4538875165311982
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 248 по событию MainScreenAppear получаем
# При проверке будет ли отличие между группами 246 и 248 по событию OffersScreenAppear получаем
# p-значение:  0.2601500947498627
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 248 по событию MainScreenAppear получаем
# При проверке будет ли отличие между группами 246 и 248 по событию CartScreenAppear получаем
# p-значение:  0.1081995040532513
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 246 и 248 по событию MainScreenAppear получаем
# При проверке будет ли отличие между группами 246 и 248 по событию PaymentScreenSuccessful получаем
# p-значение:  0.239054894032515
# ...

# %%
# Проверяю, будет ли отличие между группами 247 и 248 по событиям

# объявляем функцию difference_247_248 с двумя параметрами: # successes и trials
def difference_247_248(successes, trials): # заголовок функции
    # пропорция успехов в 247 группе:
    p246 = successes[0]/trials[0]

    # пропорция успехов в 248 группе:
    p248 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference = p246 - p248 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  
    
    p_value = (1 - distr.cdf(abs(z_value))) * 2
    print('p-значение: ', p_value)
   
    if p_value < alpha_1:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    ) 
        
print('При проверке будет ли отличие между группами 247 и 248 по событию MainScreenAppear получаем')
MainScreenAppear_event =  difference_247_248(successes_MainScreenAppear_3, trials_3)

print('При проверке будет ли отличие между группами 247 и 248 по событию OffersScreenAppear получаем')
OffersScreenAppear =  difference_247_248(successes_OffersScreenAppear_3, trials_3)

print('При проверке будет ли отличие между группами 247 и 248 по событию CartScreenAppear получаем')
CartScreenAppear =  difference_247_248(successes_CartScreenAppear_3, trials_3)

print('При проверке будет ли отличие между группами 247 и 248 по событию PaymentScreenSuccessful получаем')
PaymentScreenSuccessful =  difference_247_248(successes_PaymentScreenSuccessful_3, trials_3)
# Out:
# При проверке будет ли отличие между группами 247 и 248 по событию MainScreenAppear получаем
# p-значение:  0.8456296578773543
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 247 и 248 по событию OffersScreenAppear получаем
# p-значение:  0.8916023466886049
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 247 и 248 по событию CartScreenAppear получаем
# p-значение:  0.7508350927093224
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между группами 247 и 248 по событию PaymentScreenSuccessful получаем
# p-значение:  0.6668983315395216
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными

# %%
# Проверяю, будет ли отличие между группами 247 и 248 по событиям

# объявляем функцию difference_247_248 с двумя параметрами: # successes и trials
def difference_246_247_248(successes, trials): # заголовок функции
    # пропорция успехов в 246 и 247 группах:
    p246_247 = successes[0]/trials[0]

    # пропорция успехов в 248 группе:
    p248 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference_246_247_248 = p246_247 - p248 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference_246_247_248 / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  
    
    p_value = (1 - distr.cdf(abs(z_value))) * 2
    print('p-значение: ', p_value)
   
    if p_value < alpha_1:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    ) 
        
print('При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию MainScreenAppear получаем')
MainScreenAppear_event =  difference_246_247_248(successes_MainScreenAppear_4, trials_4)

print('При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию OffersScreenAppear получаем')
OffersScreenAppear =  difference_246_247_248(successes_OffersScreenAppear_4, trials_4)

print('При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию CartScreenAppear получаем')
CartScreenAppear =  difference_246_247_248(successes_CartScreenAppear_4, trials_4)

print('При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию PaymentScreenSuccessful получаем')
PaymentScreenSuccessful =  difference_246_247_248(successes_PaymentScreenSuccessful_4, trials_4)
# Out:
# При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию MainScreenAppear получаем
# p-значение:  0.5865055483330501
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию OffersScreenAppear получаем
# p-значение:  0.4674653325203759
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию CartScreenAppear получаем
# p-значение:  0.2675917289544225
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# При проверке будет ли отличие между объединенной группой 246 и 247 с экспериментальной группой 248 по событию PaymentScreenSuccessful получаем
# p-значение:  0.668624761940358
# ...

# %% [markdown]
# # Промежуточный вывод 5.10.:
#
# После проведения вычислений со скорректированным уровнем значимости видно, что результаты не изменились. Можно сказать, что разбиение на группы работает корректно.

# %% [markdown]
# ## Итоговый вывод:
#
# Целью проекта является решить повлияет ли изменение шрифта во всём приложении на поведение пользователей с помощью исследования результатов А/А/В - эксперимента.
#
# # Описание данных
# Каждая запись в логе — это действие пользователя, или событие.
# •	EventName — название события;
# •	DeviceIDHash — уникальный идентификатор пользователя;
# •	EventTimestamp — время события;
# •	ExpId — номер эксперимента: 246 и 247 — контрольные группы, а 248 — экспериментальная.
#
# После изучения общей информации о файле можно сделать вывод, что предоставленные данные выглядят правдоподобно. В файле нет пропусков, но есть дубликаты, которые удалила. Типы данных корректные.
#
# С файлом проделаны следующие действия:
# - В данных 244 126 строк, которые разделены на 4 столбца,
# - Столбцы переименованы: 'EventName' в 'event_name', 'DeviceIDHash' в 'user_ID', 'EventTimestamp' в 'timestamp', 'ExpId' в 'group',
# - В файл добавлены столбцы 'time'(даты и время) и 'date'(даты),
# - Т.к. доля дубликатов от исходных данных 1,69 %, удалила их.
#
# Определила с помощью гистограммы по дате и количеству событий, что данные полные с 2019-08-01, т.к. видно, что событий ранее в разы меньше, чем в августе. Более ранние данные отбросила.
# Получается, что обладаю данными на самом деле за период времени  с '2019-08-01' по '2019-08-07'.
#
# В результате отбрасывания старых данных потеряны:
# - 796 событий (было - 243 713, стало - 242 917),
# - 9 пользователей (было - 7 551, стало - 7 542).
#
# Доли, которые составляют отброшенные данные от исходных данных:
# - Отбрасываемые события от исходных данных составляют 0.01 (т.е. 1 %),
# - Отброшенные пользователи от исходного количества 0.002 (т.е. 0,2 %).
#
# Проверила и убедилась, что после отбрасывания старых данных остались пользователи из всех трёх экспериментальных групп.
# - 246 группа - 2 489 пользователей,
# - 247 группа - 2 520 пользователей,
# - 248 группа - 2 542 пользователя.
#
# Посчитала для каждого события долю пользователей от всех:
# - MainScreenAppear - 99 %,
# - OffersScreenAppear - 61 %,
# - CartScreenAppear	- 50 %,
# - PaymentScreenSuccessful	- 47 %.
#
# Посчитала долю пользователей, проходящих на следующий шаг воронки:
# - OffersScreenAppear - 62 %,
# - CartScreenAppear - 81 %,
# - PaymentScreenSuccessful	95 %.
#
# Больше всего теряется пользователей на шаге от MainScreenAppear к OffersScreenAppear. Не проходят дальше 48 % пользователей. В связи с этим нужно лучше прорабатывать механику, чтобы пользователи переходили к OffersScreenAppear.
#
# Самое популярное событие: MainScreenAppear	(произошло 119 101 раз).
#
# Посчитала долю пользователей, совершивших событие 'MainScreenAppear':
# - 246 группа - 0.99,
# - 247 группа - 0.99,
# - 248 группа - 0.98.
#
# # После проведения вычислений с уровнем значимости 0,5 видно, что нет оснований считать доли разными, т.е. нельзя говорить о статистически значимом различии между группами.
#
# # После проведения вычислений со скорректированным уровнем значимости видно, что результаты не изменились.
#
# # Нельзя сказать, что разбиение на группы работает некорректно.
#
# # Вывод: тест следует остановить и признать, что изменение шрифта во всём приложении никак не повлияет на пользователей. Поэтому дизайнеры смело могут поменять шрифт.
